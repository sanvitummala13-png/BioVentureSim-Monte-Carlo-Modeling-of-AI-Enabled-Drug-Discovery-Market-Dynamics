# %%
# Setup: make the project root importable
import sys, os
sys.path.append(os.path.abspath('..'))
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
from src import config

# %%
from src.assumptions import load_assumptions
from src.sensitivity import run_sensitivity
a = load_assumptions()
sens = run_sensitivity(a, n_sims=1000, save=False)
sens

# %%
from src.visualization import plot_tornado
plot_tornado(sens)
from IPython.display import Image
Image(str(config.FIGURES_DIR / '05_tornado.png'))
